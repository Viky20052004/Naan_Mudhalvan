# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
ds=pd.read_csv("/content/statsfinal.csv") #reading the csv dataset
ds
# Out:
#       Unnamed: 0        Date  Q-P1  Q-P2  Q-P3  Q-P4      S-P1      S-P2  \
# 0              0  13-06-2010  5422  3725   576   907  17187.74  23616.50
# 1              1  14-06-2010  7047   779  3578  1574  22338.99   4938.86
# 2              2  15-06-2010  1572  2082   595  1145   4983.24  13199.88
# 3              3  16-06-2010  5657  2399  3140  1672  17932.69  15209.66
# 4              4  17-06-2010  3668  3207  2184   708  11627.56  20332.38
# ...          ...         ...   ...   ...   ...   ...       ...       ...
# 4595        4595  30-01-2023  2476  3419   525  1359   7848.92  21676.46
# 4596        4596  31-01-2023  7446   841  4825  1311  23603.82   5331.94
# 4597        4597  01-02-2023  6289  3143  3588   474  19936.13  19926.62
# 4598        4598  02-02-2023  3122  1188  5899   517   9896.74   7531.92
# 4599        4599  03-02-2023  1234  3854  2321   406   3911.78  24434.36
#
#           S-P3      S-P4
# 0      3121.92   6466.91
# 1     19392.76  11222.62
# ...

# %%
d=ds["Date"] #seperating the date from the dataset
p1=ds["Q-P1"] #number of product 1 sold
p2=ds["Q-P2"] #number of product 2 sold
p3=ds["Q-P3"] #number of product 3 sold
p4=ds["Q-P4"] #number of product 4 sold
#varibles to count total number of products sold in a perticular month every year
m1=0
m2=0
m3=0
m4=0
m5=0
m6=0
m7=0
m8=0
m9=0
m10=0
m11=0
m12=0
#varibles to count the number of yaers with the sales data in a perticular month
mc1=0
mc2=0
mc3=0
mc4=0
mc5=0
mc6=0
mc7=0
mc8=0
mc9=0
mc10=0
mc11=0
mc12=0
s2=0
for i in range(len(d)):
  s1=d[i].split("-")
  m=int(s1[1]) #identifying the month
  #addind the sales data in perticular month
  if m==1:
    m1+=p1[i]
    if s2!=m:
      mc1+=1
  elif m==2:
    m2+=p1[i]
    if s2!=m:
      mc2+=1
  elif m==3:
    m3+=p1[i]
    if s2!=m:
      mc3+=1
  elif m==4:
    m4+=p1[i]
    if s2!=m:
      mc4+=1
  elif m==5:
    m5+=p1[i]
    if s2!=m:
      mc5+=1
  elif m==6:
    m6+=p1[i]
    if s2!=m:
      mc6+=1
  elif m==7:
    m7+=p1[i]
    if s2!=m:
      mc7+=1
  elif m==8:
    m8+=p1[i]
    if s2!=m:
      mc8+=1
  elif m==9:
    m9+=p1[i]
    if s2!=m:
      mc9+=1
  elif m==10:
    m10+=p1[i]
    if s2!=m:
      mc10+=1
  elif m==11:
    m11+=p1[i]
    if s2!=m:
      mc11+=1
  elif m==12:
    m12+=p1[i]
    if s2!=m:
      mc12+=1
  s2=m

# %%
#Calculating Average sales of a product in a month
mf1=m1/mc1
mf2=m2/mc2
mf3=m3/mc3
mf4=m4/mc4
mf5=m5/mc5
mf6=m6/mc6
mf7=m7/mc7
mf8=m8/mc8
mf9=m9/mc9
mf10=m10/mc10
mf11=m11/mc11
mf12=m12/mc12
x=range(1,13)
y=[mf1,mf2,mf3,mf4,mf5,mf6,mf7,mf8,mf9,mf10,mf11,mf12]

plt.plot(x,y) #ploting the graph
plt.show()

# %%
import csv
with open('product4.csv', 'w', newline='') as file:
  writer = csv.writer(file)
  writer.writerow(["Month","Avg Sales"])
  for i in range(12):
    writer.writerow([x[i],y[i]])

# %%
with open('year.csv', 'w', newline='') as file:
  writer = csv.writer(file)
  s4=0
  writer.writerow(["Year"])
  for i in range(len(d)):
    s3=d[i].split("-")
    m=int(s3[2])
    if s4!=m:
      writer.writerow([m])
    s4=m
